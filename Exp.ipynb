# %%
# This mounts your Google Drive to the Colab VM.
from google.colab import drive
drive.mount('/content/drive')

FOLDERNAME = '4yp_rewrite/'
assert FOLDERNAME is not None, "[!] Enter the foldername."

# Now that we've mounted your Drive, this ensures that
# the Python interpreter of the Colab VM can load
# python files from within it.
import sys
sys.path.append('/content/drive/My Drive/{}'.format(FOLDERNAME))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install colorama
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import os
# the base Google Drive directory
root_dir = "/content/drive/My Drive/"

# choose where you want your project files to be saved
project_folder = FOLDERNAME

def create_and_set_working_directory(project_folder):
  # check if your project folder exists. if not, it will be created.
  if os.path.isdir(root_dir + project_folder) == False:
    os.mkdir(root_dir + project_folder)
    print(root_dir + project_folder + ' did not exist but was created.')

  # change the OS to use your project folder as the working directory
  os.chdir(root_dir + project_folder)

  # create a test file to make sure it shows up in the right place

  print('\nYour working directory was changed to ' + root_dir + project_folder + \
        "You can also run !pwd to confirm the current working directory." )

create_and_set_working_directory(project_folder)
# Out:
# Your working directory was changed to /content/drive/My Drive/4yp_rewrite/You can also run !pwd to confirm the current working directory.

# %%
# Initialize the dataframe if not already existed.
dataframe_name = 'Results_dataframe/Incidence_Concatenated_Full.pkl'
import pandas as pd
import os
if os.path.isfile(dataframe_name):
  df = pd.read_pickle(dataframe_name)
  print('File already exists. Loading from existing file.')
else:
  column_names = ['Exp id', 'Stage specification', 'Phase specification', 'Ventricle', 'Learning rate', 
                  'Droppout rate', 'Num of epochs', 'Training acc', 'Validation acc', 'Test acc',
                  'Training loss', 'Validation loss']
  print('New file has been generated')
  df = pd. DataFrame(columns=column_names)
df.head()
# Out:
# File already exists. Loading from existing file.
#   Exp id Stage specification Phase specification Ventricle  Learning rate  \
# 0   7311           Incidence        Concatenated      Full       0.000001
# 1   7312           Incidence        Concatenated      Full       0.000001
# 2   7313           Incidence        Concatenated      Full       0.000001
# 3   7314           Incidence        Concatenated      Full       0.000001
# 4   7315           Incidence        Concatenated      Full       0.000001
#
#    Droppout rate Num of epochs  Training acc  Validation acc   Test acc  \
# 0          0.650           100     82.620988       57.142857  60.852572
# 1          0.650            50     74.283456       58.214286  62.342928
# 2          0.675           100     82.201592       57.500000  61.298217
# 3          0.675            50     71.195521       62.857143  61.710988
# 4          0.700           100     76.333829       57.857143  59.146698
#
#    Training loss  Validation loss
# ...

# %%
print(len(df))
# Out:
# 34

# %%
import time
create_and_set_working_directory(project_folder)
startTime = time.time()
# %run 'Exp76.py'
df.loc[len(df.index)] = [args1.code, args1.stage_spec, args1.phase_spec, args1.ventricle, 
                         args1.base_lr, args1.dpr, args1.num_epochs, ave_performance[0], 
                         ave_performance[1], ave_performance[2], ave_performance[3], 
                         ave_performance[4]]
create_and_set_working_directory(project_folder)
df.to_pickle(dataframe_name)
executionTime = (time.time() - startTime)
print('Execution time in seconds: ' + str(executionTime))
# Out:
# Your working directory was changed to /content/drive/My Drive/4yp_rewrite/You can also run !pwd to confirm the current working directory.
# Reading point clouds from directories...
# Reading point clouds from directories...
# Single phase data(ES/ED) are read correctly
# Number in class 0:  539
# Number in class 1:  294
# Dataset for PointNet binary disease classification has been initialised (gender not specified).
# Total number of data in the dataset: 833
#
#  Fold 1
# Class balance is ensured in all data division
# Training epoch 200/200 in progress
#  Fold 2
# Class balance is ensured in all data division
# Training epoch 200/200 in progress
#  Fold 3
# Class balance is ensured in all data division
# Training epoch 200/200 in progress
#  Fold 4
# Class balance is ensured in all data division
# Training epoch 200/200 in progressModel saved at fold: 4
# File name temp.npy is changed to Exp7681.npy
# Dropout rate: 0.7
# Final test accuracy: 0.6294106606606606
# ...

# %%
df.tail()
# Out:
#    Exp id Stage specification Phase specification Ventricle  Learning rate  \
# 29   7641          Prevalence                  ED     Right       0.000001
# 30   7651          Prevalence                  ES     Right       0.000001
# 31   7661          Prevalence        Concatenated      Left       0.000001
# 32   7671          Prevalence                  ED      Left       0.000001
# 33   7681          Prevalence                  ES      Left       0.000001
#
#     Droppout rate Num of epochs  Training acc  Validation acc   Test acc  \
# 29            0.7           200     69.645544       64.204545  62.063626
# 30            0.7           200     70.542738       62.215909  63.743431
# 31            0.7           200     73.206384       67.329545  67.004505
# 32            0.7           200     71.250274       68.750000  66.854354
# 33            0.7           200     69.034804       61.931818  62.941066
#
#     Training loss  Validation loss
# 29       0.577312         0.660300
# ...
